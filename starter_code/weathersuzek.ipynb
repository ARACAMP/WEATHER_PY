# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key 

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_data=[]
# Error city counter
i=0
for city in cities:

    # Build query URL based on current element in units
    query_url = url + "appid=" + api_key + "&q=" + city + "&units=imperial"

    # Get weather data
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    
    try:
        weather_data.append({
            "City":city,
            "Cloudiness": weather_json["clouds"]["all"], 
            "Country":weather_json["sys"]["country"], 
            "Date":weather_json["dt"], 
            "Humidity":weather_json["main"]["humidity"], 
            "Lat":weather_json["coord"]["lat"], 
            "Lng":weather_json["coord"]["lon"], 
            "Max Temp":weather_json["main"]["temp_max"], 
            "Wind Speed":weather_json["wind"]["speed"]})
        #print(city + " :Ok.")
    except Exception as e:
        i+=1
        print("{}- City: {}: Error with type: {} and value: {}".format(i, city, type(e), e))
print("Done with the requests.")
# Out:
# 1- City: vaitupu: Error with type: <class 'KeyError'> and value: 'clouds'
# 2- City: tabiauea: Error with type: <class 'KeyError'> and value: 'clouds'
# 3- City: maarianhamina: Error with type: <class 'KeyError'> and value: 'clouds'
# 4- City: tokzar: Error with type: <class 'KeyError'> and value: 'clouds'
# 5- City: nizhneyansk: Error with type: <class 'KeyError'> and value: 'clouds'
# 6- City: raozan: Error with type: <class 'KeyError'> and value: 'clouds'
# 7- City: taolanaro: Error with type: <class 'KeyError'> and value: 'clouds'
# 8- City: samalaeulu: Error with type: <class 'KeyError'> and value: 'clouds'
# 9- City: bengkulu: Error with type: <class 'KeyError'> and value: 'clouds'
# 10- City: barentsburg: Error with type: <class 'KeyError'> and value: 'clouds'
# 11- City: saleaula: Error with type: <class 'KeyError'> and value: 'clouds'
# 12- City: mahadday weyne: Error with type: <class 'KeyError'> and value: 'clouds'
# 13- City: belushya guba: Error with type: <class 'KeyError'> and value: 'clouds'
# 14- City: lolua: Error with type: <class 'KeyError'> and value: 'clouds'
# 15- City: cockburn harbour: Error with type: <class 'KeyError'> and value: 'clouds'
# 16- City: acuna: Error with type: <class 'KeyError'> and value: 'clouds'
# 17- City: tsihombe: Error with type: <class 'KeyError'> and value: 'clouds'
# 18- City: illoqqortoormiut: Error with type: <class 'KeyError'> and value: 'clouds'
# 19- City: jeluko: Error with type: <class 'KeyError'> and value: 'clouds'
# 20- City: phan rang: Error with type: <class 'KeyError'> and value: 'clouds'
# 21- City: porto santo: Error with type: <class 'KeyError'> and value: 'clouds'
# 22- City: mys shmidta: Error with type: <class 'KeyError'> and value: 'clouds'
# 23- City: bor: Error with type: <class 'KeyError'> and value: 'clouds'
# 24- City: tumannyy: Error with type: <class 'KeyError'> and value: 'clouds'
# 25- City: manguiring: Error with type: <class 'KeyError'> and value: 'clouds'
# 26- City: samusu: Error with type: <class 'KeyError'> and value: 'clouds'
# 27- City: attawapiskat: Error with type: <class 'KeyError'> and value: 'clouds'
# 28- City: marcona: Error with type: <class 'KeyError'> and value: 'clouds'
# 29- City: san martin de hidalgo: Error with type: <class 'KeyError'> and value: 'clouds'
# 30- City: sentyabrskiy: Error with type: <class 'KeyError'> and value: 'clouds'
# 31- City: rungata: Error with type: <class 'KeyError'> and value: 'clouds'
# 32- City: karaul: Error with type: <class 'KeyError'> and value: 'clouds'
# 33- City: palabuhanratu: Error with type: <class 'KeyError'> and value: 'clouds'
# 34- City: kousseri: Error with type: <class 'KeyError'> and value: 'clouds'
# 35- City: haibowan: Error with type: <class 'KeyError'> and value: 'clouds'
# 36- City: dzhusaly: Error with type: <class 'KeyError'> and value: 'clouds'
# 37- City: korla: Error with type: <class 'KeyError'> and value: 'clouds'
# 38- City: ngukurr: Error with type: <class 'KeyError'> and value: 'clouds'
# 39- City: amderma: Error with type: <class 'KeyError'> and value: 'clouds'
# 40- City: pemangkat: Error with type: <class 'KeyError'> and value: 'clouds'
# 41- City: skalistyy: Error with type: <class 'KeyError'> and value: 'clouds'
# 42- City: grand river south east: Error with type: <class 'KeyError'> and value: 'clouds'
# 43- City: liniere: Error with type: <class 'KeyError'> and value: 'clouds'
# 44- City: kazalinsk: Error with type: <class 'KeyError'> and value: 'clouds'
# 45- City: sakakah: Error with type: <class 'KeyError'> and value: 'clouds'
# 46- City: kamenskoye: Error with type: <class 'KeyError'> and value: 'clouds'
# 47- City: ndele: Error with type: <class 'KeyError'> and value: 'clouds'
# 48- City: bargal: Error with type: <class 'KeyError'> and value: 'clouds'
# 49- City: azimur: Error with type: <class 'KeyError'> and value: 'clouds'
# 50- City: olafsvik: Error with type: <class 'KeyError'> and value: 'clouds'
# 51- City: grand centre: Error with type: <class 'KeyError'> and value: 'clouds'
# 52- City: armacao dos buzios: Error with type: <class 'KeyError'> and value: 'clouds'
# 53- City: raga: Error with type: <class 'KeyError'> and value: 'clouds'
# 54- City: sedelnikovo: Error with type: <class 'KeyError'> and value: 'clouds'
# 55- City: sumbawa: Error with type: <class 'KeyError'> and value: 'clouds'
# 56- City: yefira: Error with type: <class 'KeyError'> and value: 'clouds'
# 57- City: krasnoselkup: Error with type: <class 'KeyError'> and value: 'clouds'
# 58- City: chagda: Error with type: <class 'KeyError'> and value: 'clouds'
# 59- City: aktash: Error with type: <class 'KeyError'> and value: 'clouds'
# 60- City: umm durman: Error with type: <class 'KeyError'> and value: 'clouds'
# 61- City: mikonos: Error with type: <class 'KeyError'> and value: 'clouds'
# 62- City: umzimvubu: Error with type: <class 'KeyError'> and value: 'clouds'
# 63- City: alotau: Error with type: <class 'KeyError'> and value: 'clouds'
# 64- City: kadykchan: Error with type: <class 'KeyError'> and value: 'clouds'
# 65- City: yunjinghong: Error with type: <class 'KeyError'> and value: 'clouds'
# 66- City: el faiyum: Error with type: <class 'KeyError'> and value: 'clouds'
# 67- City: fulitun: Error with type: <class 'KeyError'> and value: 'clouds'
# 68- City: bolungarvik: Error with type: <class 'KeyError'> and value: 'clouds'
# 69- City: maghama: Error with type: <class 'KeyError'> and value: 'clouds'
# 70- City: meyungs: Error with type: <class 'KeyError'> and value: 'clouds'
# 71- City: sataua: Error with type: <class 'KeyError'> and value: 'clouds'
# 72- City: kaeng khlo: Error with type: <class 'KeyError'> and value: 'clouds'
# 73- City: uk: Error with type: <class 'KeyError'> and value: 'clouds'
# Done with the requests.

# %%
df=pd.DataFrame.from_dict(weather_data)
df.head.()
# Out:
#   File "<ipython-input-9-61f8c9dcc3a1>", line 2
#     df.head.()
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Obtain the x and y coordinates for each of the three city types
latitude=df["Lat"]
max_tem=df["Max Temp"]

# Build the scatter plots for each city types
plt.scatter(latitude, max_tem, marker="o", facecolor="lightcoral", 
            edgecolors="black", alpha=0.5)

#Limit the chart
plt.ylim(-180, 180)
plt.xlim(-90, 90)

# Incorporate the other graph properties
plt.grid(color='r', linestyle='-', linewidth=0.5)

# Create a legend
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature F")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Obtain the x and y coordinates for each of the three city types
latitude=df["Lat"]
hum=df["Humidity"]


# Build the scatter plots for each city types
plt.scatter(latitude, hum, marker="o", facecolor="lightcoral", edgecolors="black", alpha=0.5)

#Limit the chart
plt.ylim(-180, 180)
plt.xlim(-90, 90)

# Incorporate the other graph properties
plt.grid(color='r', linestyle='-', linewidth=0.5)

# Create a legend
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Obtain the x and y coordinates for each of the three city types
latitude=df["Lat"]
cloud=df["Cloudiness"]

# Build the scatter plots for each city types
plt.scatter(latitude, cloud, marker="o", facecolor="lightcoral", edgecolors="black", alpha=0.5)

#Limit the chart
plt.ylim(-180, 180)
plt.xlim(-90, 90)

# Incorporate the other graph properties
plt.grid(color='r', linestyle='-', linewidth=0.5)

# Create a legend
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Obtain the x and y coordinates for each of the three city types
latitude=df["Lat"]
wind=df["Wind Speed"]

# Build the scatter plots for each city types
plt.scatter(latitude, wind, marker="o", facecolor="lightcoral", edgecolors="black", alpha=0.5)

#Limit the chart
plt.ylim(-180, 180)
plt.xlim(-90, 90)

# Incorporate the other graph properties
plt.grid(color='r', linestyle='-', linewidth=0.5)

# Create a legend
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.show()
